# %%
# CELL 1: MASTER INSTALLATION
import sys
import subprocess

def install_dependencies():
    packages = [
        "pandas",
        "numpy",
        "requests",
        "folium",
        "reverse_geocoder",
        "geopy",
        "scikit-learn",
        "seaborn",
        "matplotlib",
        "xgboost",
        "catboost",
        "optuna",
        "onnxmltools",
        "onnxruntime",
        "joblib",
        "scipy",
        "global_land_mask"
    ]
    
    print("🚀 Starting Master Installation of Project Dependencies...")
    for package in packages:
        try:
            subprocess.check_call([sys.executable, "-m", "pip", "install", package])
            print(f"✅ Successfully installed {package}")
        except Exception as e:
            print(f"❌ Failed to install {package}: {e}")
            
    print("\n🎉 Phase 0 Complete! Your environment is ready.")

install_dependencies()
# Out:
# 🚀 Starting Master Installation of Project Dependencies...
# ✅ Successfully installed pandas
# ✅ Successfully installed numpy
# ✅ Successfully installed requests
# ✅ Successfully installed folium
# ✅ Successfully installed reverse_geocoder
# ✅ Successfully installed geopy
# ✅ Successfully installed scikit-learn
# ✅ Successfully installed seaborn
# ✅ Successfully installed matplotlib
# ✅ Successfully installed xgboost
# ✅ Successfully installed catboost
# ✅ Successfully installed optuna
# ✅ Successfully installed onnxmltools
# ✅ Successfully installed onnxruntime
# ✅ Successfully installed joblib
# ✅ Successfully installed scipy
# ✅ Successfully installed global_land_mask
#
# 🎉 Phase 0 Complete! Your environment is ready.
